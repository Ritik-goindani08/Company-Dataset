# %%
import pandas as pd

# %%
f500 = pd.read_csv("Datasets/f500.csv")

# %% [markdown]
# # Attribute
#     * shape
#     * dtypes

# %%
f500.shape # no of row , no of col
# Out:
# (500, 17)

# %%
f500.dtypes # col dataTypes
# Out:
# company                      object
# rank                          int64
# revenues                      int64
# revenue_change              float64
# profits                     float64
# assets                        int64
# profit_change               float64
# ceo                          object
# industry                     object
# sector                       object
# previous_rank                 int64
# country                      object
# hq_location                  object
# website                      object
# years_on_global_500_list      int64
# employees                     int64
# total_stockholder_equity      int64
# dtype: object

# %%
f500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 17 columns):
# company                     500 non-null object
# rank                        500 non-null int64
# revenues                    500 non-null int64
# revenue_change              498 non-null float64
# profits                     499 non-null float64
# assets                      500 non-null int64
# profit_change               436 non-null float64
# ceo                         500 non-null object
# industry                    500 non-null object
# sector                      500 non-null object
# previous_rank               500 non-null int64
# country                     500 non-null object
# hq_location                 500 non-null object
# website                     500 non-null object
# years_on_global_500_list    500 non-null int64
# employees                   500 non-null int64
# total_stockholder_equity    500 non-null int64
# dtypes: float64(3), int64(7), object(7)
# ...

# %%
# MIN OR MAX VALUE MAI SE CHECK KAREGA KY 25%,50%,75% VALUE KNSI HOGI 
a1 = pd.Series([0,100])  
a1.describe()
# Out:
# count      2.000000
# mean      50.000000
# std       70.710678
# min        0.000000
# 25%       25.000000
# 50%       50.000000
# 75%       75.000000
# max      100.000000
# dtype: float64

# %%
# Syntax: DataFrame.describe()
f500.describe()
# Out:
#              rank       revenues  revenue_change       profits        assets  \
# count  500.000000     500.000000      498.000000    499.000000  5.000000e+02
# mean   250.500000   55416.358000        4.538353   3055.203206  2.436323e+05
# std    144.481833   45725.478963       28.549067   5171.981071  4.851937e+05
# min      1.000000   21609.000000      -67.300000 -13038.000000  3.717000e+03
# 25%    125.750000   29003.000000       -5.900000    556.950000  3.658850e+04
# 50%    250.500000   40236.000000        0.550000   1761.600000  7.326150e+04
# 75%    375.250000   63926.750000        6.975000   3954.000000  1.805640e+05
# max    500.000000  485873.000000      442.300000  45687.000000  3.473238e+06
#
#        profit_change  previous_rank  years_on_global_500_list     employees  \
# count     436.000000     500.000000                500.000000  5.000000e+02
# mean       24.152752     222.134000                 15.036000  1.339983e+05
# ...

# %%
f500.describe(include = ["O"])
# Out:
#                   company              ceo                       industry  \
# count                 500              500                            500
# unique                500              500                             58
# top     Johnson & Johnson  Herbert K. Haas  Banks: Commercial and Savings
# freq                    1                1                             51
#
#             sector country     hq_location               website
# count          500     500             500                   500
# unique          21      34             235                   500
# top     Financials     USA  Beijing, China  http://www.cisco.com
# freq           118     132              56                     1

# %%
f500.describe(include = "all")
# Out:
#                   company        rank       revenues  revenue_change  \
# count                 500  500.000000     500.000000      498.000000
# unique                500         NaN            NaN             NaN
# top     Johnson & Johnson         NaN            NaN             NaN
# freq                    1         NaN            NaN             NaN
# mean                  NaN  250.500000   55416.358000        4.538353
# std                   NaN  144.481833   45725.478963       28.549067
# min                   NaN    1.000000   21609.000000      -67.300000
# 25%                   NaN  125.750000   29003.000000       -5.900000
# 50%                   NaN  250.500000   40236.000000        0.550000
# 75%                   NaN  375.250000   63926.750000        6.975000
# max                   NaN  500.000000  485873.000000      442.300000
#
#              profits        assets  profit_change              ceo  \
# count     499.000000  5.000000e+02     436.000000              500
# ...

# %%
# By default 5 value
f500.head()
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 0                   Walmart     1    485873             0.8  13643.0  198825
# 1                State Grid     2    315199            -4.4   9571.3  489838
# 2             Sinopec Group     3    267518            -9.1   1257.9  310726
# 3  China National Petroleum     4    262573           -12.3   1867.5  585619
# 4              Toyota Motor     5    254694             7.7  16899.3  437575
#
#    profit_change                  ceo                  industry  \
# 0           -7.2  C. Douglas McMillon     General Merchandisers
# 1           -6.2              Kou Wei                 Utilities
# 2          -65.0            Wang Yupu        Petroleum Refining
# 3          -73.7        Zhang Jianhua        Petroleum Refining
# 4          -12.3          Akio Toyoda  Motor Vehicles and Parts
#
#                    sector  previous_rank country      hq_location  \
# ...

# %%
f500.head(10)
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 0                   Walmart     1    485873             0.8  13643.0  198825
# 1                State Grid     2    315199            -4.4   9571.3  489838
# 2             Sinopec Group     3    267518            -9.1   1257.9  310726
# 3  China National Petroleum     4    262573           -12.3   1867.5  585619
# 4              Toyota Motor     5    254694             7.7  16899.3  437575
# 5                Volkswagen     6    240264             1.5   5937.3  432116
# 6         Royal Dutch Shell     7    240033           -11.8   4575.0  411275
# 7        Berkshire Hathaway     8    223604             6.1  24074.0  620854
# 8                     Apple     9    215639            -7.7  45687.0  321686
# 9               Exxon Mobil    10    205004           -16.7   7840.0  330314
#
#    profit_change                  ceo  \
# 0           -7.2  C. Douglas McMillon
# 1           -6.2              Kou Wei
# ...

# %%
f500.tail()
# Out:
#                             company  rank  revenues  revenue_change  profits  \
# 495  Teva Pharmaceutical Industries   496     21903            11.5    329.0
# 496        New China Life Insurance   497     21796           -13.3    743.9
# 497       Wm. Morrison Supermarkets   498     21741           -11.3    406.4
# 498                             TUI   499     21655            -5.5   1151.7
# 499                      AutoNation   500     21609             3.6    430.5
#
#      assets  profit_change                 ceo  \
# 495   92890          -79.3   Yitzhak Peterburg
# 496  100609          -45.6            Wan Feng
# 497   11630           20.4      David T. Potts
# 498   16247          195.5   Friedrich Joussen
# 499   10060           -2.7  Michael J. Jackson
#
#                             industry              sector  previous_rank  \
# 495                  Pharmaceuticals         Health Care              0
# ...

# %%
f500.tail(10)
# Out:
#                                    company  rank  revenues  revenue_change  \
# 490                          National Grid   491     22036            -3.2
# 491                         Dollar General   492     21987             7.9
# 492                         Telecom Italia   493     21941           -17.4
# 493               Xiamen ITG Holding Group   494     21930            34.3
# 494  Xinjiang Guanghui Industry Investment   495     21919            31.1
# 495         Teva Pharmaceutical Industries   496     21903            11.5
# 496               New China Life Insurance   497     21796           -13.3
# 497              Wm. Morrison Supermarkets   498     21741           -11.3
# 498                                    TUI   499     21655            -5.5
# 499                             AutoNation   500     21609             3.6
#
#      profits  assets  profit_change                 ceo  \
# 490  10150.6   82310          160.2      John Pettigrew
# ...

# %%
# dataset header
f500.columns
# Out:
# Index(['company', 'rank', 'revenues', 'revenue_change', 'profits', 'assets',
#        'profit_change', 'ceo', 'industry', 'sector', 'previous_rank',
#        'country', 'hq_location', 'website', 'years_on_global_500_list',
#        'employees', 'total_stockholder_equity'],
#       dtype='object')

# %%
# regular python mai hum srf col ki value chahiye hoti thi tw loop lagaty thy
f500['company'].head()
# Out:
# 0                     Walmart
# 1                  State Grid
# 2               Sinopec Group
# 3    China National Petroleum
# 4                Toyota Motor
# Name: company, dtype: object

# %%
f500[['company','rank','industry']].head()
# Out:
#                     company  rank                  industry
# 0                   Walmart     1     General Merchandisers
# 1                State Grid     2                 Utilities
# 2             Sinopec Group     3        Petroleum Refining
# 3  China National Petroleum     4        Petroleum Refining
# 4              Toyota Motor     5  Motor Vehicles and Parts

# %% [markdown]
# * iloc will use when we have integer indexing
# * loc will use when we have label indexing

# %%
f500.iloc[0] # Fetch Row Data
# Out:
# company                                    Walmart
# rank                                             1
# revenues                                    485873
# revenue_change                                 0.8
# profits                                      13643
# assets                                      198825
# profit_change                                 -7.2
# ceo                            C. Douglas McMillon
# industry                     General Merchandisers
# sector                                   Retailing
# previous_rank                                    1
# country                                        USA
# hq_location                        Bentonville, AR
# website                     http://www.walmart.com
# years_on_global_500_list                        23
# employees                                  2300000
# total_stockholder_equity                     77798
# Name: 0, dtype: object

# %%
f500.iloc[0:5] # Fetch Row Data
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 0                   Walmart     1    485873             0.8  13643.0  198825
# 1                State Grid     2    315199            -4.4   9571.3  489838
# 2             Sinopec Group     3    267518            -9.1   1257.9  310726
# 3  China National Petroleum     4    262573           -12.3   1867.5  585619
# 4              Toyota Motor     5    254694             7.7  16899.3  437575
#
#    profit_change                  ceo                  industry  \
# 0           -7.2  C. Douglas McMillon     General Merchandisers
# 1           -6.2              Kou Wei                 Utilities
# 2          -65.0            Wang Yupu        Petroleum Refining
# 3          -73.7        Zhang Jianhua        Petroleum Refining
# 4          -12.3          Akio Toyoda  Motor Vehicles and Parts
#
#                    sector  previous_rank country      hq_location  \
# ...

# %%
f500.iloc[0:5,0:5]
# Out:
#                     company  rank  revenues  revenue_change  profits
# 0                   Walmart     1    485873             0.8  13643.0
# 1                State Grid     2    315199            -4.4   9571.3
# 2             Sinopec Group     3    267518            -9.1   1257.9
# 3  China National Petroleum     4    262573           -12.3   1867.5
# 4              Toyota Motor     5    254694             7.7  16899.3

# %%
f500.iloc[0:5,[0,2,4]]
# Out:
#                     company  revenues  profits
# 0                   Walmart    485873  13643.0
# 1                State Grid    315199   9571.3
# 2             Sinopec Group    267518   1257.9
# 3  China National Petroleum    262573   1867.5
# 4              Toyota Motor    254694  16899.3

# %%
f500.loc[0]
# Out:
# company                                    Walmart
# rank                                             1
# revenues                                    485873
# revenue_change                                 0.8
# profits                                      13643
# assets                                      198825
# profit_change                                 -7.2
# ceo                            C. Douglas McMillon
# industry                     General Merchandisers
# sector                                   Retailing
# previous_rank                                    1
# country                                        USA
# hq_location                        Bentonville, AR
# website                     http://www.walmart.com
# years_on_global_500_list                        23
# employees                                  2300000
# total_stockholder_equity                     77798
# Name: 0, dtype: object

# %%
f500.loc[0:5]
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 0                   Walmart     1    485873             0.8  13643.0  198825
# 1                State Grid     2    315199            -4.4   9571.3  489838
# 2             Sinopec Group     3    267518            -9.1   1257.9  310726
# 3  China National Petroleum     4    262573           -12.3   1867.5  585619
# 4              Toyota Motor     5    254694             7.7  16899.3  437575
# 5                Volkswagen     6    240264             1.5   5937.3  432116
#
#    profit_change                  ceo                  industry  \
# 0           -7.2  C. Douglas McMillon     General Merchandisers
# 1           -6.2              Kou Wei                 Utilities
# 2          -65.0            Wang Yupu        Petroleum Refining
# 3          -73.7        Zhang Jianhua        Petroleum Refining
# 4          -12.3          Akio Toyoda  Motor Vehicles and Parts
# ...

# %%
f500.loc[0:5,"company":"profits"]
# Out:
#                     company  rank  revenues  revenue_change  profits
# 0                   Walmart     1    485873             0.8  13643.0
# 1                State Grid     2    315199            -4.4   9571.3
# 2             Sinopec Group     3    267518            -9.1   1257.9
# 3  China National Petroleum     4    262573           -12.3   1867.5
# 4              Toyota Motor     5    254694             7.7  16899.3
# 5                Volkswagen     6    240264             1.5   5937.3

# %%
f500.loc[0:5,["company","revenues","profits"]]
# Out:
#                     company  revenues  profits
# 0                   Walmart    485873  13643.0
# 1                State Grid    315199   9571.3
# 2             Sinopec Group    267518   1257.9
# 3  China National Petroleum    262573   1867.5
# 4              Toyota Motor    254694  16899.3
# 5                Volkswagen    240264   5937.3

# %%
f500["company"].head()
# Out:
# 0                     Walmart
# 1                  State Grid
# 2               Sinopec Group
# 3    China National Petroleum
# 4                Toyota Motor
# Name: company, dtype: object

# %%
f500[["company","rank"]].head()
# Out:
#                     company  rank
# 0                   Walmart     1
# 1                State Grid     2
# 2             Sinopec Group     3
# 3  China National Petroleum     4
# 4              Toyota Motor     5

# %%
# slicing se row fetch hoskti hai lkn index number se nh in pandas
f500[0:5]
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 0                   Walmart     1    485873             0.8  13643.0  198825
# 1                State Grid     2    315199            -4.4   9571.3  489838
# 2             Sinopec Group     3    267518            -9.1   1257.9  310726
# 3  China National Petroleum     4    262573           -12.3   1867.5  585619
# 4              Toyota Motor     5    254694             7.7  16899.3  437575
#
#    profit_change                  ceo                  industry  \
# 0           -7.2  C. Douglas McMillon     General Merchandisers
# 1           -6.2              Kou Wei                 Utilities
# 2          -65.0            Wang Yupu        Petroleum Refining
# 3          -73.7        Zhang Jianhua        Petroleum Refining
# 4          -12.3          Akio Toyoda  Motor Vehicles and Parts
#
#                    sector  previous_rank country      hq_location  \
# ...

# %%
type(f500["company"])
# Out:
# pandas.core.series.Series

# %%
type(f500.loc[0])
# Out:
# pandas.core.series.Series

# %%
type(f500.iloc[:,0:2])
# Out:
# pandas.core.frame.DataFrame

# %%
f500.columns
# Out:
# Index(['company', 'rank', 'revenues', 'revenue_change', 'profits', 'assets',
#        'profit_change', 'ceo', 'industry', 'sector', 'previous_rank',
#        'country', 'hq_location', 'website', 'years_on_global_500_list',
#        'employees', 'total_stockholder_equity'],
#       dtype='object')

# %%
country_frq = {}
for c in f500['country']:
    if c in country_frq:
        country_frq[c] += 1
    else:
        country_frq[c] = 1
country_frq
# Out:
# {'USA': 132,
#  'China': 109,
#  'Japan': 51,
#  'Germany': 29,
#  'Netherlands': 14,
#  'Britain': 24,
#  'South Korea': 15,
#  'Switzerland': 14,
#  'France': 29,
#  'Taiwan': 6,
#  'Singapore': 3,
#  'Italy': 7,
#  'Russia': 4,
#  'Spain': 9,
#  'Brazil': 7,
#  'Mexico': 2,
#  'Luxembourg': 1,
#  'India': 7,
#  'Malaysia': 1,
#  'Thailand': 1,
#  'Australia': 7,
#  'Belgium': 1,
#  'Norway': 1,
#  'Canada': 11,
#  'Ireland': 4,
#  'Indonesia': 1,
#  'Denmark': 1,
#  'Saudi Arabia': 1,
#  'Sweden': 3,
#  'Finland': 1,
#  'Venezuela': 1,
#  'Turkey': 1,
#  'U.A.E': 1,
#  'Israel': 1}

# %%
f500["country"].value_counts()
# Out:
# USA             132
# China           109
# Japan            51
# France           29
# Germany          29
# Britain          24
# South Korea      15
# Switzerland      14
# Netherlands      14
# Canada           11
# Spain             9
# Australia         7
# Brazil            7
# Italy             7
# India             7
# Taiwan            6
# Ireland           4
# Russia            4
# Sweden            3
# Singapore         3
# Mexico            2
# Norway            1
# Malaysia          1
# Belgium           1
# Denmark           1
# Israel            1
# Finland           1
# Thailand          1
# U.A.E             1
# Luxembourg        1
# Venezuela         1
# Indonesia         1
# Turkey            1
# Saudi Arabia      1
# Name: country, dtype: int64

# %%
f500["country"].value_counts()["Netherlands"]
# Out:
# 14

# %%
frq = f500["country"].value_counts()
frq["Netherlands"]
# Out:
# 14

# %%
f500.head()
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 0                   Walmart     1    485873             0.8  13643.0  198825
# 1                State Grid     2    315199            -4.4   9571.3  489838
# 2             Sinopec Group     3    267518            -9.1   1257.9  310726
# 3  China National Petroleum     4    262573           -12.3   1867.5  585619
# 4              Toyota Motor     5    254694             7.7  16899.3  437575
#
#    profit_change                  ceo                  industry  \
# 0           -7.2  C. Douglas McMillon     General Merchandisers
# 1           -6.2              Kou Wei                 Utilities
# 2          -65.0            Wang Yupu        Petroleum Refining
# 3          -73.7        Zhang Jianhua        Petroleum Refining
# 4          -12.3          Akio Toyoda  Motor Vehicles and Parts
#
#                    sector  previous_rank country      hq_location  \
# ...

# %%
f500.iloc[1,1] = 3

# %%
f500.head()
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 0                   Walmart     1    485873             0.8  13643.0  198825
# 1                State Grid     3    315199            -4.4   9571.3  489838
# 2             Sinopec Group     3    267518            -9.1   1257.9  310726
# 3  China National Petroleum     4    262573           -12.3   1867.5  585619
# 4              Toyota Motor     5    254694             7.7  16899.3  437575
#
#    profit_change                  ceo                  industry  \
# 0           -7.2  C. Douglas McMillon     General Merchandisers
# 1           -6.2              Kou Wei                 Utilities
# 2          -65.0            Wang Yupu        Petroleum Refining
# 3          -73.7        Zhang Jianhua        Petroleum Refining
# 4          -12.3          Akio Toyoda  Motor Vehicles and Parts
#
#                    sector  previous_rank country      hq_location  \
# ...

# %%
f500.loc[3,"revenues"] = 101010

# %%
f500.head()
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 0                   Walmart     1    485873             0.8  13643.0  198825
# 1                State Grid     3    315199            -4.4   9571.3  489838
# 2             Sinopec Group     3    267518            -9.1   1257.9  310726
# 3  China National Petroleum     4    101010           -12.3   1867.5  585619
# 4              Toyota Motor     5    254694             7.7  16899.3  437575
#
#    profit_change                  ceo                  industry  \
# 0           -7.2  C. Douglas McMillon     General Merchandisers
# 1           -6.2              Kou Wei                 Utilities
# 2          -65.0            Wang Yupu        Petroleum Refining
# 3          -73.7        Zhang Jianhua        Petroleum Refining
# 4          -12.3          Akio Toyoda  Motor Vehicles and Parts
#
#                    sector  previous_rank country      hq_location  \
# ...

# %%
f500.isnull().head()
# Out:
#    company   rank  revenues  revenue_change  profits  assets  profit_change  \
# 0    False  False     False           False    False   False          False
# 1    False  False     False           False    False   False          False
# 2    False  False     False           False    False   False          False
# 3    False  False     False           False    False   False          False
# 4    False  False     False           False    False   False          False
#
#      ceo  industry  sector  previous_rank  country  hq_location  website  \
# 0  False     False   False          False    False        False    False
# 1  False     False   False          False    False        False    False
# 2  False     False   False          False    False        False    False
# 3  False     False   False          False    False        False    False
# 4  False     False   False          False    False        False    False
#
#    years_on_global_500_list  employees  total_stockholder_equity
# ...

# %%
f500.isnull().sum()
# Out:
# company                      0
# rank                         0
# revenues                     0
# revenue_change               2
# profits                      1
# assets                       0
# profit_change               64
# ceo                          0
# industry                     0
# sector                       0
# previous_rank                0
# country                      0
# hq_location                  0
# website                      0
# years_on_global_500_list     0
# employees                    0
# total_stockholder_equity     0
# dtype: int64

# %%
f500.notnull().head()
# Out:
#    company  rank  revenues  revenue_change  profits  assets  profit_change  \
# 0     True  True      True            True     True    True           True
# 1     True  True      True            True     True    True           True
# 2     True  True      True            True     True    True           True
# 3     True  True      True            True     True    True           True
# 4     True  True      True            True     True    True           True
#
#     ceo  industry  sector  previous_rank  country  hq_location  website  \
# 0  True      True    True           True     True         True     True
# 1  True      True    True           True     True         True     True
# 2  True      True    True           True     True         True     True
# 3  True      True    True           True     True         True     True
# 4  True      True    True           True     True         True     True
#
#    years_on_global_500_list  employees  total_stockholder_equity
# ...

# %%
f500.notnull().sum()
# Out:
# company                     500
# rank                        500
# revenues                    500
# revenue_change              498
# profits                     499
# assets                      500
# profit_change               436
# ceo                         500
# industry                    500
# sector                      500
# previous_rank               500
# country                     500
# hq_location                 500
# website                     500
# years_on_global_500_list    500
# employees                   500
# total_stockholder_equity    500
# dtype: int64

# %%
f500.notnull().sum()["rank"]
# Out:
# 500
